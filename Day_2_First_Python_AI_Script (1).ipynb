# %%
print("Hello, AI World!")
print("This is my first Python AI script.")
# Out:
# Hello, AI World!
# This is my first Python AI script.

# %%
from collections import Counter

sentence = input("Enter a sentence: ")

words = sentence.lower().split()
word_frequency = Counter(words)

print("\nWord Frequency:")
for word, count in word_frequency.items():
    print(f"{word}: {count}")
# Out:
# Enter a sentence: Python is easy and Python is powerful
#
# Word Frequency:
# python: 2
# is: 2
# easy: 1
# and: 1
# powerful: 1

# %%
import re

text = input("Enter text to clean: ")

cleaned_text = text.lower()
cleaned_text = re.sub(r'[^\w\s]', '', cleaned_text)
cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()

print("\nOriginal Text:")
print(text)

print("\nCleaned Text:")
print(cleaned_text)
# Out:
# Enter text to clean: Hello!!!   Python,   AI World...   Welcome!!!
#
# Original Text:
# Hello!!!   Python,   AI World...   Welcome!!!
#
# Cleaned Text:
# hello python ai world welcome
